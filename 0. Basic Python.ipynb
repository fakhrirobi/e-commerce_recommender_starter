# %% [markdown]
# # Basic Python

# %% [markdown]
# This is a variables

# %%
a = 1

b = 1.5
c = [1, 2, 3, 4] 
d = {'a': 3,
     'b': 4}

# %%
# Out:
# 3

# %% [markdown]
# Print using a `print()` syntax

# %%
print(a)
print(b)
print(c)
print(d)
# Out:
# 1
# 1.5
# [1, 2, 3, 4]
# {'a': 3, 'b': 4}

# %% [markdown]
# Operate the variables

# %%
sum_ = a + b
sub_ = a - b
mul_ = a * b
div_ = a / b

# %%
print(sum_, sub_, mul_, div_)
# Out:
# 2.5 -0.5 1.5 0.6666666666666666

# %% [markdown]
# Accessing variables

# %%
print(c[1]) 
print(d['b'])
# Out:
# 2
# 4

# %% [markdown]
# Looping

# %%
for num in c:
    print(num)
# Out:
# 1
# 2
# 3
# 4

# %%
help(d)
# Out:
# Help on dict object:
#
# class dict(object)
#  |  dict() -> new empty dictionary
#  |  dict(mapping) -> new dictionary initialized from a mapping object's
#  |      (key, value) pairs
#  |  dict(iterable) -> new dictionary initialized as if via:
#  |      d = {}
#  |      for k, v in iterable:
#  |          d[k] = v
#  |  dict(**kwargs) -> new dictionary initialized with the name=value pairs
#  |      in the keyword argument list.  For example:  dict(one=1, two=2)
#  |
#  |  Built-in subclasses:
#  |      StgDict
#  |
#  |  Methods defined here:
#  |
#  |  __contains__(self, key, /)
#  |      True if the dictionary has the specified key, else False.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
# ...

# %%
for key, val in d.items():
    print(key, ':', val)
# Out:
# a : 3
# b : 4

# %% [markdown]
# Function

# %%
def sum(a, b):
    """Function to do summation between a & b"""
    
    return a + b

# %%
c = sum(a=5, b=3)
print(c)
# Out:
# 8

# %% [markdown]
# Load Library

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# How do you know what's in library?
#
# **Read the documentations!** *Don't be lazy*
# - [Pandas](https://pandas.pydata.org/docs/)
# - [NumPy](https://numpy.org/)
# - [Seaborn](https://seaborn.pydata.org/)
# - [Sklearn](https://scikit-learn.org/stable/)

# %% [markdown]
# ![https://pbs.twimg.com/media/FGJ7f16XoAA_2_i.jpg](https://pbs.twimg.com/media/FGJ7f16XoAA_2_i.jpg)
#
# ![https://media.datadriveninvestor.com/uploads/2020/08/1_LNI3TWutq8kj69DAUQqO4g.png](https://media.datadriveninvestor.com/uploads/2020/08/1_LNI3TWutq8kj69DAUQqO4g.png)
